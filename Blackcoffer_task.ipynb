# %% [markdown]
# <a href="https://colab.research.google.com/github/Nashra-Tazmeen/Data-Extraction-and-NLTK-/blob/main/Blackcoffer_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [634 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,593 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,304 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,592 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,547 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,036 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,308 kB]
# Fetched 9,247 kB in 2s (5,259 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 24 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor chromium-browser libfuse3-3 liblzo2-2 libudev1 snapd squashfs-tools systemd-hwe-hwdb
#   udev
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils fuse3 zenity | kdialog
# The following NEW packages will be installed:
#   apparmor chromium-browser chromium-chromedriver libfuse3-3 liblzo2-2 snapd squashfs-tools
#   systemd-hwe-hwdb udev
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 9 newly installed, 0 to remove and 23 not upgraded.
# Need to get 26.4 MB of archives.
# After this operation, 116 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.3 [595 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblzo2-2 amd64 2.10-2build3 [53.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 squashfs-tools amd64 1:4.5-3build1 [159 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.11 [78.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.11 [1,557 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfuse3-3 amd64 3.10.5-1build1 [81.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 snapd amd64 2.58+22.04.1 [23.8 MB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 chromium-browser amd64 1:85.0.4183.83-0ubuntu2.22.04.1 [49.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 chromium-chromedriver amd64 1:85.0.4183.83-0ubuntu2.22.04.1 [2,308 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.3 [2,908 B]
# Fetched 26.4 MB in 0s (61.9 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package apparmor.
# (Reading database ... 120903 files and directories currently installed.)
# Preparing to unpack .../apparmor_3.0.4-2ubuntu2.3_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.3) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../liblzo2-2_2.10-2build3_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2build3) ...
# Selecting previously unselected package squashfs-tools.
# Preparing to unpack .../squashfs-tools_1%3a4.5-3build1_amd64.deb ...
# Unpacking squashfs-tools (1:4.5-3build1) ...
# Preparing to unpack .../libudev1_249.11-0ubuntu3.11_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.11) over (249.11-0ubuntu3.10) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.11) ...
# Selecting previously unselected package udev.
# (Reading database ... 121111 files and directories currently installed.)
# Preparing to unpack .../udev_249.11-0ubuntu3.11_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.11) ...
# Selecting previously unselected package libfuse3-3:amd64.
# Preparing to unpack .../libfuse3-3_3.10.5-1build1_amd64.deb ...
# Unpacking libfuse3-3:amd64 (3.10.5-1build1) ...
# Selecting previously unselected package snapd.
# Preparing to unpack .../snapd_2.58+22.04.1_amd64.deb ...
# Unpacking snapd (2.58+22.04.1) ...
# Setting up apparmor (3.0.4-2ubuntu2.3) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up liblzo2-2:amd64 (2.10-2build3) ...
# Setting up squashfs-tools (1:4.5-3build1) ...
# Setting up udev (249.11-0ubuntu3.11) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libfuse3-3:amd64 (3.10.5-1build1) ...
# Setting up snapd (2.58+22.04.1) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.aa-prompt-listener.service → /lib/systemd/system/snapd.aa-prompt-listener.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.apparmor.service → /lib/systemd/system/snapd.apparmor.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.autoimport.service → /lib/systemd/system/snapd.autoimport.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.core-fixup.service → /lib/systemd/system/snapd.core-fixup.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.recovery-chooser-trigger.service → /lib/systemd/system/snapd.recovery-chooser-trigger.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Created symlink /etc/systemd/system/cloud-final.service.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Unit /lib/systemd/system/snapd.seeded.service is added as a dependency to a non-existent unit cloud-final.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.service → /lib/systemd/system/snapd.service.
# Created symlink /etc/systemd/system/timers.target.wants/snapd.snap-repair.timer → /lib/systemd/system/snapd.snap-repair.timer.
# Created symlink /etc/systemd/system/sockets.target.wants/snapd.socket → /lib/systemd/system/snapd.socket.
# Created symlink /etc/systemd/system/final.target.wants/snapd.system-shutdown.service → /lib/systemd/system/snapd.system-shutdown.service.
# Selecting previously unselected package chromium-browser.
# (Reading database ... 121344 files and directories currently installed.)
# Preparing to unpack .../chromium-browser_1%3a85.0.4183.83-0ubuntu2.22.04.1_amd64.deb ...
# => Installing the chromium snap
# ==> Checking connectivity with the snap store
# ===> System doesn't have a working snapd, skipping
# Unpacking chromium-browser (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_1%3a85.0.4183.83-0ubuntu2.22.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../systemd-hwe-hwdb_249.11.3_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.3) ...
# Setting up systemd-hwe-hwdb (249.11.3) ...
# Setting up chromium-browser (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Processing triggers for udev (249.11-0ubuntu3.11) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Collecting selenium
#   Downloading selenium-4.16.0-py3-none-any.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 59.0 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.23.1-py3-none-any.whl (448 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.3/448.3 kB 29.1 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.11.17)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.6)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.3.0.post0 selenium-4.16.0 trio-0.23.1 trio-websocket-0.11.1 wsproto-1.2.0

# %%
# !git clone https://github.com/Nashra-Tazmeen/Blackcoffer_task.git
# Out:
# Cloning into 'Blackcoffer_task'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 29 (delta 5), reused 23 (delta 1), pack-reused 0
# Receiving objects: 100% (29/29), 8.22 MiB | 24.26 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %% [markdown]
# **Data Extraction**

# %%
import pandas as pd
from selenium import webdriver
import os
from selenium.webdriver.common.by import By

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

driver = webdriver.Chrome(options=options)

def extract_and_save_data(url, output_file,class_name1,class_name):

    driver.get(url)
    content_element1 = driver.find_element('css selector', f'h1.{class_name1}')
    element_text1=content_element1.text


    content_element = driver.find_element(By.CLASS_NAME,class_name)
    element_text = content_element.text


    output_directory = "output_files"


    os.makedirs(output_directory, exist_ok=True)

    full_output_path = os.path.join(output_directory, output_file)


    with open(full_output_path, "w", encoding="utf-8") as file:

        file.write(f"{element_text1}\n")
        file.write(f"{element_text}\n")
        print(full_output_path)




excel_file = "/content/Blackcoffer_task/20211030 Test Assignment/Input.xlsx"


df = pd.read_excel(excel_file)

for index, row in df.iterrows():
      url = row["URL"]
      url_id = row["URL_ID"]

      output_file = f"{url_id}.txt"
      try:
        extract_and_save_data(url, output_file,'entry-title','td-post-content')
      except Exception as e:
        try:
          extract_and_save_data(url, output_file,'tdb-title-text','tdb-block-inner')
        except Exception as e:
          print('No content')

          with open('output_files/'+output_file, "w", encoding="utf-8") as file:
            file.write(f"")


driver.quit()
# Out:
# output_files/blackassign0001.txt
# output_files/blackassign0002.txt
# output_files/blackassign0003.txt
# output_files/blackassign0004.txt
# output_files/blackassign0005.txt
# output_files/blackassign0006.txt
# output_files/blackassign0007.txt
# output_files/blackassign0008.txt
# output_files/blackassign0009.txt
# output_files/blackassign0010.txt
# output_files/blackassign0011.txt
# output_files/blackassign0012.txt
# output_files/blackassign0013.txt
# output_files/blackassign0014.txt
# output_files/blackassign0015.txt
# output_files/blackassign0016.txt
# output_files/blackassign0017.txt
# output_files/blackassign0018.txt
# output_files/blackassign0019.txt
# output_files/blackassign0020.txt
# output_files/blackassign0021.txt
# output_files/blackassign0022.txt
# output_files/blackassign0023.txt
# output_files/blackassign0024.txt
# output_files/blackassign0025.txt
# output_files/blackassign0026.txt
# output_files/blackassign0027.txt
# output_files/blackassign0028.txt
# output_files/blackassign0029.txt
# output_files/blackassign0030.txt
# output_files/blackassign0031.txt
# output_files/blackassign0032.txt
# output_files/blackassign0033.txt
# output_files/blackassign0034.txt
# output_files/blackassign0035.txt
# No content
# output_files/blackassign0037.txt
# output_files/blackassign0038.txt
# output_files/blackassign0039.txt
# output_files/blackassign0040.txt
# output_files/blackassign0041.txt
# output_files/blackassign0042.txt
# output_files/blackassign0043.txt
# output_files/blackassign0044.txt
# output_files/blackassign0045.txt
# output_files/blackassign0046.txt
# output_files/blackassign0047.txt
# output_files/blackassign0048.txt
# No content
# output_files/blackassign0050.txt
# output_files/blackassign0051.txt
# output_files/blackassign0052.txt
# output_files/blackassign0053.txt
# output_files/blackassign0054.txt
# output_files/blackassign0055.txt
# output_files/blackassign0056.txt
# output_files/blackassign0057.txt
# output_files/blackassign0058.txt
# output_files/blackassign0059.txt
# output_files/blackassign0060.txt
# output_files/blackassign0061.txt
# output_files/blackassign0062.txt
# output_files/blackassign0063.txt
# output_files/blackassign0064.txt
# output_files/blackassign0065.txt
# output_files/blackassign0066.txt
# output_files/blackassign0067.txt
# output_files/blackassign0068.txt
# output_files/blackassign0069.txt
# output_files/blackassign0070.txt
# output_files/blackassign0071.txt
# output_files/blackassign0072.txt
# output_files/blackassign0073.txt
# output_files/blackassign0074.txt
# output_files/blackassign0075.txt
# output_files/blackassign0076.txt
# output_files/blackassign0077.txt
# output_files/blackassign0078.txt
# output_files/blackassign0079.txt
# output_files/blackassign0080.txt
# output_files/blackassign0081.txt
# output_files/blackassign0082.txt
# output_files/blackassign0083.txt
# output_files/blackassign0084.txt
# output_files/blackassign0085.txt
# output_files/blackassign0086.txt
# output_files/blackassign0087.txt
# output_files/blackassign0088.txt
# output_files/blackassign0089.txt
# output_files/blackassign0090.txt
# output_files/blackassign0091.txt
# output_files/blackassign0092.txt
# output_files/blackassign0093.txt
# output_files/blackassign0094.txt
# output_files/blackassign0095.txt
# output_files/blackassign0096.txt
# output_files/blackassign0097.txt
# output_files/blackassign0098.txt
# output_files/blackassign0099.txt
# output_files/blackassign0100.txt

# %%
# !pip install syllables
# Out:
# Collecting syllables
#   Downloading syllables-1.0.9-py3-none-any.whl (15 kB)
# Collecting cmudict<2.0.0,>=1.0.11 (from syllables)
#   Downloading cmudict-1.0.15-py3-none-any.whl (939 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.4/939.4 kB 12.6 MB/s eta 0:00:00
# Collecting importlib-metadata<7.0,>=5.1 (from syllables)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Collecting importlib-resources<6.0.0,>=5.10.1 (from cmudict<2.0.0,>=1.0.11->syllables)
#   Downloading importlib_resources-5.13.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7.0,>=5.1->syllables) (3.17.0)
# Installing collected packages: importlib-resources, importlib-metadata, cmudict, syllables
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 6.1.1
#     Uninstalling importlib-resources-6.1.1:
#       Successfully uninstalled importlib-resources-6.1.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.0
#     Uninstalling importlib-metadata-7.0.0:
#       Successfully uninstalled importlib-metadata-7.0.0
# Successfully installed cmudict-1.0.15 importlib-metadata-6.11.0 importlib-resources-5.13.0 syllables-1.0.9

# %%
import pandas as pd
import os
import nltk
import string
from nltk.corpus import stopwords, cmudict
from nltk.tokenize import word_tokenize, sent_tokenize, LineTokenizer
import syllables
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('cmudict')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# True

# %%
def get_words_from_file(file_path):
    file = open(file_path, 'r', encoding='latin-1')
    words = file.read().splitlines()
    words = [s.split('|')[0].strip().lower() for s in words]
    return words.copy()

def get_words_from_dir(folder_path):
    final_words = []
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)

        final_words += get_words_from_file(file_path)
    return final_words

def extract_text_from_file(file_path):
    file = open(file_path, 'r', encoding='latin-1')
    text = file.read()
    return text.lower()

def get_scores(text):
    words = word_tokenize(text)
    sentences = nltk.sent_tokenize(text)
    translator = str.maketrans("", "", string.punctuation)
    filtered_words = [word.translate(translator) for word in words if word.isalnum()]
    cleaned_words = [word for word in filtered_words if word not in stop_words]

    pronouncing_dict = cmudict.dict()
    complex_words = [word for word in filtered_words if syllables.estimate(word) > 2]
    total_syllable_count = sum([syllables.estimate(word) for word in filtered_words])
    personal_pronouns = set(['i','we','my','ours','us'])
    total_number_of_characters = sum([len(word) for word in filtered_words])

    positive_score = 0
    negative_score = 0
    for word in cleaned_words:
        if word in positive_words:
            positive_score += 1
        if word in negative_words:
            negative_score += 1
    polarity_score = (positive_score - negative_score)/((positive_score + negative_score) + 0.000001)
    subjective_score = (positive_score + negative_score) / (len(cleaned_words) +0.000001)
    average_sentence_length = len(filtered_words)/len(sentences) if len(sentences) > 0 else 0
    percentage_of_complex_words = len(complex_words)/len(filtered_words) if len(filtered_words) > 0 else 0
    fog_index = 0.4 * (average_sentence_length + percentage_of_complex_words)
    average_number_of_words_per_sentence = len(filtered_words)/len(sentences) if len(sentences) > 0 else 0
    complex_word_count = len(complex_words)
    word_count = len(cleaned_words)
    syllable_count_per_word = total_syllable_count/len(filtered_words) if len(filtered_words) > 0 else 0
    personal_pronouns_count = len([word for word in filtered_words if word in personal_pronouns])
    average_word_length = total_number_of_characters/len(filtered_words) if len(filtered_words) > 0 else 0
    return {
        'positive_score':positive_score,
        'negative_score':negative_score,
        'polarity_score':polarity_score,
        'subjective_score':subjective_score,
        'average_sentence_length':average_sentence_length,
        'percentage_of_complex_words':percentage_of_complex_words,
        'fog_index':fog_index,
        'average_number_of_words_per_sentence':average_number_of_words_per_sentence,
        'complex_word_count':complex_word_count,
        'word_count':word_count,
        'syllable_count_per_word':syllable_count_per_word,
        'personal_pronouns_count':personal_pronouns_count,
        'average_word_length':average_word_length
    }

# %%
english_stopwords = stopwords.words('english')
stop_words = set(get_words_from_dir('/content/Blackcoffer_task/20211030 Test Assignment/StopWords')) | set(english_stopwords)
positive_words = set(get_words_from_file('/content/Blackcoffer_task/20211030 Test Assignment/MasterDictionary/positive-words.txt'))- stop_words
negative_words = set(get_words_from_file('/content/Blackcoffer_task/20211030 Test Assignment/MasterDictionary/negative-words.txt'))- stop_words
folder_path = '/content/output_files'
all_scores = {}
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    text = extract_text_from_file(file_path)
    scores = get_scores(text)
    all_scores[filename] = scores
    print(filename)
# Out:
# blackassign0072.txt
# blackassign0070.txt
# blackassign0100.txt
# blackassign0047.txt
# blackassign0045.txt
# blackassign0066.txt
# blackassign0022.txt
# blackassign0083.txt
# blackassign0027.txt
# blackassign0005.txt
# blackassign0039.txt
# blackassign0009.txt
# blackassign0031.txt
# blackassign0061.txt
# blackassign0098.txt
# blackassign0090.txt
# blackassign0078.txt
# blackassign0032.txt
# blackassign0052.txt
# blackassign0035.txt
# blackassign0013.txt
# blackassign0042.txt
# blackassign0099.txt
# blackassign0043.txt
# blackassign0029.txt
# blackassign0092.txt
# blackassign0034.txt
# blackassign0084.txt
# blackassign0008.txt
# blackassign0060.txt
# blackassign0095.txt
# blackassign0096.txt
# blackassign0001.txt
# blackassign0089.txt
# blackassign0058.txt
# blackassign0017.txt
# blackassign0059.txt
# blackassign0069.txt
# blackassign0049.txt
# blackassign0002.txt
# blackassign0073.txt
# blackassign0016.txt
# blackassign0080.txt
# blackassign0054.txt
# blackassign0044.txt
# blackassign0023.txt
# blackassign0018.txt
# blackassign0012.txt
# blackassign0010.txt
# blackassign0088.txt
# blackassign0085.txt
# blackassign0026.txt
# blackassign0048.txt
# blackassign0004.txt
# blackassign0011.txt
# blackassign0021.txt
# blackassign0071.txt
# blackassign0087.txt
# blackassign0077.txt
# blackassign0062.txt
# blackassign0057.txt
# blackassign0081.txt
# blackassign0082.txt
# blackassign0068.txt
# blackassign0030.txt
# blackassign0091.txt
# blackassign0064.txt
# blackassign0025.txt
# blackassign0050.txt
# blackassign0079.txt
# blackassign0051.txt
# blackassign0006.txt
# blackassign0086.txt
# blackassign0036.txt
# blackassign0003.txt
# blackassign0063.txt
# blackassign0053.txt
# blackassign0019.txt
# blackassign0007.txt
# blackassign0046.txt
# blackassign0074.txt
# blackassign0015.txt
# blackassign0014.txt
# blackassign0028.txt
# blackassign0075.txt
# blackassign0055.txt
# blackassign0056.txt
# blackassign0076.txt
# blackassign0065.txt
# blackassign0024.txt
# blackassign0041.txt
# blackassign0038.txt
# blackassign0093.txt
# blackassign0037.txt
# blackassign0097.txt
# blackassign0067.txt
# blackassign0033.txt
# blackassign0040.txt
# blackassign0094.txt
# blackassign0020.txt

# %%
import pandas as pd

def apply_scores(row):
  scores = ['positive_score','negative_score','polarity_score','subjective_score','average_sentence_length',
                'percentage_of_complex_words','fog_index','average_number_of_words_per_sentence','complex_word_count',
                'word_count','syllable_count_per_word','personal_pronouns_count','average_word_length']
  for score in scores:
    row[score] = all_scores[row['URL_ID']+'.txt'][score]
  return row



df = pd.read_excel('/content/Blackcoffer_task/20211030 Test Assignment/Input.xlsx')
df = df.apply(apply_scores,axis = 1)
df.to_excel('output.xlsx', index=False)

# %%
all_scores
# Out:
# {'blackassign0072.txt': {'positive_score': 53,
#   'negative_score': 23,
#   'polarity_score': 0.3947368369113574,
#   'subjective_score': 0.17798594806092283,
#   'average_sentence_length': 14.26923076923077,
#   'percentage_of_complex_words': 0.1509433962264151,
#   'fog_index': 5.768069666182875,
#   'average_number_of_words_per_sentence': 14.26923076923077,
#   'complex_word_count': 168,
#   'word_count': 427,
#   'syllable_count_per_word': 1.5471698113207548,
#   'personal_pronouns_count': 5,
#   'average_word_length': 4.520215633423181},
#  'blackassign0070.txt': {'positive_score': 35,
#   'negative_score': 16,
#   'polarity_score': 0.37254901230296056,
#   'subjective_score': 0.07715582439159482,
#   'average_sentence_length': 22.014285714285716,
#   'percentage_of_complex_words': 0.24140168721609345,
#   'fog_index': 8.902274960600725,
#   'average_number_of_words_per_sentence': 22.014285714285716,
#   'complex_word_count': 372,
#   'word_count': 661,
#   'syllable_count_per_word': 1.8221933809214796,
#   'personal_pronouns_count': 8,
#   'average_word_length': 5.070084360804672},
#  'blackassign0100.txt': {'positive_score': 1,
#   'negative_score': 0,
#   'polarity_score': 0.9999990000010001,
#   'subjective_score': 0.33333322222225925,
#   'average_sentence_length': 7.0,
#   'percentage_of_complex_words': 0.0,
#   'fog_index': 2.8000000000000003,
#   'average_number_of_words_per_sentence': 7.0,
#   'complex_word_count': 0,
#   'word_count': 3,
#   'syllable_count_per_word': 1.1428571428571428,
#   'personal_pronouns_count': 0,
#   'average_word_length': 3.857142857142857},
#  'blackassign0047.txt': {'positive_score': 14,
#   'negative_score': 5,
#   'polarity_score': 0.47368418559556913,
#   'subjective_score': 0.05491329463897892,
#   'average_sentence_length': 17.675,
#   'percentage_of_complex_words': 0.3041018387553041,
#   'fog_index': 7.191640735502123,
#   'average_number_of_words_per_sentence': 17.675,
#   'complex_word_count': 215,
#   'word_count': 346,
#   'syllable_count_per_word': 1.9391796322489392,
#   'personal_pronouns_count': 0,
#   'average_word_length': 5.415841584158416},
#  'blackassign0045.txt': {'positive_score': 75,
#   'negative_score': 39,
#   'polarity_score': 0.31578947091412746,
#   'subjective_score': 0.16989567783920168,
#   'average_sentence_length': 177.6,
#   'percentage_of_complex_words': 0.19594594594594594,
#   'fog_index': 71.11837837837838,
#   'average_number_of_words_per_sentence': 177.6,
#   'complex_word_count': 348,
#   'word_count': 671,
#   'syllable_count_per_word': 1.679054054054054,
#   'personal_pronouns_count': 15,
#   'average_word_length': 4.739864864864865},
#  'blackassign0066.txt': {'positive_score': 29,
#   'negative_score': 23,
#   'polarity_score': 0.11538461316568052,
#   'subjective_score': 0.08981001711604487,
#   'average_sentence_length': 17.329268292682926,
#   'percentage_of_complex_words': 0.18859957776213934,
#   'fog_index': 7.007147148178027,
#   'average_number_of_words_per_sentence': 17.329268292682926,
#   'complex_word_count': 268,
#   'word_count': 579,
#   'syllable_count_per_word': 1.6629134412385644,
#   'personal_pronouns_count': 16,
#   'average_word_length': 4.769880365939479},
#  'blackassign0022.txt': {'positive_score': 12,
#   'negative_score': 10,
#   'polarity_score': 0.09090908677685969,
#   'subjective_score': 0.1294117639446367,
#   'average_sentence_length': 14.892857142857142,
#   'percentage_of_complex_words': 0.20623501199040767,
#   'fog_index': 6.03963686193902,
#   'average_number_of_words_per_sentence': 14.892857142857142,
#   'complex_word_count': 86,
#   'word_count': 170,
#   'syllable_count_per_word': 1.79136690647482,
#   'personal_pronouns_count': 5,
#   'average_word_length': 4.942446043165468},
#  'blackassign0083.txt': {'positive_score': 0,
#   'negative_score': 0,
#   'polarity_score': 0.0,
#   'subjective_score': 0.0,
#   'average_sentence_length': 3.0,
#   'percentage_of_complex_words': 0.0,
#   'fog_index': 1.2000000000000002,
#   'average_number_of_words_per_sentence': 3.0,
#   'complex_word_count': 0,
#   'word_count': 3,
#   'syllable_count_per_word': 1.6666666666666667,
#   'personal_pronouns_count': 0,
#   'average_word_length': 6.0},
#  'blackassign0027.txt': {'positive_score': 19,
#   'negative_score': 26,
#   'polarity_score': -0.1555555520987655,
#   'subjective_score': 0.08875739627464024,
#   'average_sentence_length': 27.020833333333332,
#   'percentage_of_complex_words': 0.17579028527370855,
#   'fog_index': 10.878649447442818,
#   'average_number_of_words_per_sentence': 27.020833333333332,
#   'complex_word_count': 228,
#   'word_count': 507,
#   'syllable_count_per_word': 1.6445643793369313,
#   'personal_pronouns_count': 27,
#   'average_word_length': 4.575173477255205},
#  'blackassign0005.txt': {'positive_score': 19,
#   'negative_score': 8,
#   'polarity_score': 0.4074073923182447,
#   'subjective_score': 0.08282208563551507,
#   'average_sentence_length': 16.875,
#   'percentage_of_complex_words': 0.2474074074074074,
#   'fog_index': 6.848962962962964,
#   'average_number_of_words_per_sentence': 16.875,
#   'complex_word_count': 167,
#   'word_count': 326,
#   'syllable_count_per_word': 1.8355555555555556,
#   'personal_pronouns_count': 6,
#   'average_word_length': 5.41925925925926},
#  'blackassign0039.txt': {'positive_score': 48,
#   'negative_score': 57,
#   'polarity_score': -0.0857142848979592,
#   'subjective_score': 0.11679644035951453,
#   'average_sentence_length': 18.02857142857143,
#   'percentage_of_complex_words': 0.2461701003697834,
#   'fog_index': 7.309896611576486,
#   'average_number_of_words_per_sentence': 18.02857142857143,
#   'complex_word_count': 466,
#   'word_count': 899,
#   'syllable_count_per_word': 1.826201796090861,
#   'personal_pronouns_count': 0,
#   'average_word_length': 5.0950871632329635},
#  'blackassign0009.txt': {'positive_score': 37,
#   'negative_score': 51,
#   'polarity_score': -0.1590909072830579,
#   'subjective_score': 0.15547703152742573,
#   'average_sentence_length': 19.040816326530614,
#   'percentage_of_complex_words': 0.38478027867095393,
#   'fog_index': 7.770238642080627,
#   'average_number_of_words_per_sentence': 19.040816326530614,
#   'complex_word_count': 359,
#   'word_count': 566,
#   'syllable_count_per_word': 2.257234726688103,
#   'personal_pronouns_count': 3,
#   'average_word_length': 6.273311897106109},
#  'blackassign0031.txt': {'positive_score': 65,
#   'negative_score': 35,
#   'polarity_score': 0.299999997,
#   'subjective_score': 0.12406947875425622,
#   'average_sentence_length': 19.662790697674417,
#   'percentage_of_complex_words': 0.2820816085156712,
#   'fog_index': 7.977948922476036,
#   'average_number_of_words_per_sentence': 19.662790697674417,
#   'complex_word_count': 477,
#   'word_count': 806,
#   'syllable_count_per_word': 1.9343583678296865,
#   'personal_pronouns_count': 2,
#   'average_word_length': 5.377291543465405},
#  'blackassign0061.txt': {'positive_score': 47,
#   'negative_score': 18,
#   'polarity_score': 0.44615383928994096,
#   'subjective_score': 0.113438045177246,
#   'average_sentence_length': 20.833333333333332,
#   'percentage_of_complex_words': 0.304,
#   'fog_index': 8.454933333333333,
#   'average_number_of_words_per_sentence': 20.833333333333332,
#   'complex_word_count': 342,
#   'word_count': 573,
#   'syllable_count_per_word': 1.9964444444444445,
#   'personal_pronouns_count': 0,
#   'average_word_length': 5.597333333333333},
#  'blackassign0098.txt': {'positive_score': 6,
#   'negative_score': 3,
#   'polarity_score': 0.33333329629630043,
#   'subjective_score': 0.04433497515105923,
#   'average_sentence_length': 18.0,
#   'percentage_of_complex_words': 0.26262626262626265,
#   'fog_index': 7.305050505050506,
#   'average_number_of_words_per_sentence': 18.0,
#   'complex_word_count': 104,
#   'word_count': 203,
#   'syllable_count_per_word': 1.8737373737373737,
#   'personal_pronouns_count': 0,
#   'average_word_length': 5.409090909090909},
#  'blackassign0090.txt': {'positive_score': 32,
#   'negative_score': 48,
#   'polarity_score': -0.19999999750000003,
#   'subjective_score': 0.16064256995854906,
#   'average_sentence_length': 16.445945945945947,
#   'percentage_of_complex_words': 0.19967132292522596,
#   'fog_index': 6.65824690754847,
#   'average_number_of_words_per_sentence': 16.445945945945947,
#   'complex_word_count': 243,
#   'word_count': 498,
#   'syllable_count_per_word': 1.6828266228430566,
#   'personal_pronouns_count': 37,
#   'average_word_length': 4.796220213640098},
#  'blackassign0078.txt': {'positive_score': 36,
#   'negative_score': 24,
#   'polarity_score': 0.19999999666666674,
#   'subjective_score': 0.10830324890197969,
#   'average_sentence_length': 29.175,
#   'percentage_of_complex_words': 0.22964867180805484,
#   'fog_index': 11.761859468723223,
#   'average_number_of_words_per_sentence': 29.175,
#   'complex_word_count': 268,
#   'word_count': 554,
#   'syllable_count_per_word': 1.8517566409597257,
#   'personal_pronouns_count': 1,
#   'average_word_length': 5.282776349614396},
#  'blackassign0032.txt': {'positive_score': 65,
#   'negative_score': 28,
#   'polarity_score': 0.3978494580876403,
#   'subjective_score': 0.14832535861511106,
#   'average_sentence_length': 17.083333333333332,
#   'percentage_of_complex_words': 0.19451219512195123,
#   'fog_index': 6.911138211382114,
#   'average_number_of_words_per_sentence': 17.083333333333332,
#   'complex_word_count': 319,
#   'word_count': 627,
#   'syllable_count_per_word': 1.7134146341463414,
#   'personal_pronouns_count': 18,
#   'average_word_length': 4.7701219512195125},
#  'blackassign0052.txt': {'positive_score': 57,
#   'negative_score': 37,
#   'polarity_score': 0.2127659551833409,
#   'subjective_score': 0.12947658384369617,
#   'average_sentence_length': 17.071428571428573,
#   'percentage_of_complex_words': 0.19089958158995815,
#   'fog_index': 6.9049312612074125,
#   'average_number_of_words_per_sentence': 17.071428571428573,
#   'complex_word_count': 365,
#   'word_count': 726,
#   'syllable_count_per_word': 1.7102510460251046,
#   'personal_pronouns_count': 10,
#   'average_word_length': 4.792887029288703},
#  'blackassign0035.txt': {'positive_score': 22,
#   'negative_score': 11,
#   'polarity_score': 0.33333332323232356,
#   'subjective_score': 0.10280373799749615,
#   'average_sentence_length': 15.934782608695652,
#   'percentage_of_complex_words': 0.2373806275579809,
#   'fog_index': 6.468865294501454,
#   'average_number_of_words_per_sentence': 15.934782608695652,
#   'complex_word_count': 174,
#   'word_count': 321,
#   'syllable_count_per_word': 1.7598908594815825,
#   'personal_pronouns_count': 7,
#   'average_word_length': 4.9890859481582535},
#  'blackassign0013.txt': {'positive_score': 38,
#   'negative_score': 13,
#   'polarity_score': 0.49019606881968497,
#   'subjective_score': 0.1881918812243842,
#   'average_sentence_length': 24.4,
#   'percentage_of_complex_words': 0.3180327868852459,
#   'fog_index': 9.887213114754099,
#   'average_number_of_words_per_sentence': 24.4,
#   'complex_word_count': 194,
#   'word_count': 271,
#   'syllable_count_per_word': 1.957377049180328,
#   'personal_pronouns_count': 3,
#   'average_word_length': 5.380327868852459},
#  'blackassign0042.txt': {'positive_score': 54,
#   'negative_score': 24,
#   'polarity_score': 0.3846153796844182,
#   'subjective_score': 0.1266233764178192,
#   'average_sentence_length': 24.294117647058822,
#   'percentage_of_complex_words': 0.20157384987893462,
#   'fog_index': 9.798276598775104,
#   'average_number_of_words_per_sentence': 24.294117647058822,
#   'complex_word_count': 333,
#   'word_count': 616,
#   'syllable_count_per_word': 1.7009685230024214,
#   'personal_pronouns_count': 21,
#   'average_word_length': 4.8056900726392255},
#  'blackassign0099.txt': {'positive_score': 0,
#   'negative_score': 0,
#   'polarity_score': 0.0,
#   'subjective_score': 0.0,
#   'average_sentence_length': 5.0,
#   'percentage_of_complex_words': 0.4,
#   'fog_index': 2.16,
#   'average_number_of_words_per_sentence': 5.0,
#   'complex_word_count': 2,
#   'word_count': 3,
#   'syllable_count_per_word': 2.2,
#   'personal_pronouns_count': 0,
#   'average_word_length': 6.4},
#  'blackassign0043.txt': {'positive_score': 1,
#   'negative_score': 0,
#   'polarity_score': 0.9999990000010001,
#   'subjective_score': 0.24999993750001562,
#   'average_sentence_length': 9.0,
#   'percentage_of_complex_words': 0.3333333333333333,
#   'fog_index': 3.733333333333334,
#   'average_number_of_words_per_sentence': 9.0,
#   'complex_word_count': 3,
#   'word_count': 4,
#   'syllable_count_per_word': 1.6666666666666667,
#   'personal_pronouns_count': 0,
#   'average_word_length': 4.333333333333333},
#  'blackassign0029.txt': {'positive_score': 2,
#   'negative_score': 0,
#   'polarity_score': 0.99999950000025,
#   'subjective_score': 0.49999987500003124,
#   'average_sentence_length': 7.0,
#   'percentage_of_complex_words': 0.42857142857142855,
#   'fog_index': 2.9714285714285715,
#   'average_number_of_words_per_sentence': 7.0,
#   'complex_word_count': 3,
#   'word_count': 4,
#   'syllable_count_per_word': 2.0,
#   'personal_pronouns_count': 0,
#   'average_word_length': 5.428571428571429},
#  'blackassign0092.txt': {'positive_score': 1,
#   'negative_score': 0,
#   'polarity_score': 0.9999990000010001,
#   'subjective_score': 0.24999993750001562,
#   'average_sentence_length': 9.0,
#   'percentage_of_complex_words': 0.1111111111111111,
#   'fog_index': 3.6444444444444444,
#   'average_number_of_words_per_sentence': 9.0,
#   'complex_word_count': 1,
#   'word_count': 4,
#   'syllable_count_per_word': 1.4444444444444444,
#   'personal_pronouns_count': 0,
#   'average_word_length': 4.111111111111111},
#  'blackassign0034.txt': {'positive_score': 42,
#   'negative_score': 22,
#   'polarity_score': 0.31249999511718757,
#   'subjective_score': 0.11918063292517574,
#   'average_sentence_length': 20.142857142857142,
#   'percentage_of_complex_words': 0.21591804570527975,
#   'fog_index': 8.143510075424969,
#   'average_number_of_words_per_sentence': 20.142857142857142,
#   'complex_word_count': 274,
#   'word_count': 537,
#   'syllable_count_per_word': 1.756501182033097,
#   'personal_pronouns_count': 18,
#   'average_word_length': 5.003940110323089},
#  'blackassign0084.txt': {'positive_score': 1,
#   'negative_score': 0,
#   'polarity_score': 0.9999990000010001,
#   'subjective_score': 0.16666663888889352,
#   'average_sentence_length': 9.0,
#   'percentage_of_complex_words': 0.3333333333333333,
#   'fog_index': 3.733333333333334,
#   'average_number_of_words_per_sentence': 9.0,
#   'complex_word_count': 3,
#   'word_count': 6,
#   'syllable_count_per_word': 1.8888888888888888,
#   'personal_pronouns_count': 0,
#   'average_word_length': 5.555555555555555},
#  'blackassign0008.txt': {'positive_score': 27,
#   'negative_score': 9,
#   'polarity_score': 0.4999999861111115,
#   'subjective_score': 0.07947019850006579,
#   'average_sentence_length': 20.405405405405407,
#   'percentage_of_complex_words': 0.38675496688741723,
#   'fog_index': 8.31686414891713,
#   'average_number_of_words_per_sentence': 20.405405405405407,
#   'complex_word_count': 292,
#   'word_count': 453,
#   'syllable_count_per_word': 2.249006622516556,
#   'personal_pronouns_count': 3,
#   'average_word_length': 6.2543046357615895},
#  'blackassign0060.txt': {'positive_score': 5,
#   'negative_score': 2,
#   'polarity_score': 0.4285713673469475,
#   'subjective_score': 0.08860759381509375,
#   'average_sentence_length': 18.8,
#   'percentage_of_complex_words': 0.18085106382978725,
#   'fog_index': 7.592340425531916,
#   'average_number_of_words_per_sentence': 18.8,
#   'complex_word_count': 34,
#   'word_count': 79,
#   'syllable_count_per_word': 1.696808510638298,
#   'personal_pronouns_count': 1,
#   'average_word_length': 4.797872340425532},
#  'blackassign0095.txt': {'positive_score': 6,
#   'negative_score': 24,
#   'polarity_score': -0.5999999800000007,
#   'subjective_score': 0.10135135100894814,
#   'average_sentence_length': 17.0,
#   'percentage_of_complex_words': 0.2238562091503268,
#   'fog_index': 6.889542483660131,
#   'average_number_of_words_per_sentence': 17.0,
#   'complex_word_count': 137,
#   'word_count': 296,
#   'syllable_count_per_word': 1.7565359477124183,
#   'personal_pronouns_count': 4,
#   'average_word_length': 4.967320261437909},
#  'blackassign0096.txt': {'positive_score': 24,
#   'negative_score': 54,
#   'polarity_score': -0.3846153796844182,
#   'subjective_score': 0.15175097246741057,
#   'average_sentence_length': 22.8125,
#   'percentage_of_complex_words': 0.2502283105022831,
#   'fog_index': 9.225091324200914,
#   'average_number_of_words_per_sentence': 22.8125,
#   'complex_word_count': 274,
#   'word_count': 514,
#   'syllable_count_per_word': 1.8292237442922374,
#   'personal_pronouns_count': 2,
#   'average_word_length': 5.187214611872146},
#  'blackassign0001.txt': {'positive_score': 26,
#   'negative_score': 6,
#   'polarity_score': 0.6249999804687506,
#   'subjective_score': 0.06584362126369625,
#   'average_sentence_length': 19.046875,
#   'percentage_of_complex_words': 0.1509433962264151,
#   'fog_index': 7.679127358490567,
#   'average_number_of_words_per_sentence': 19.046875,
#   'complex_word_count': 184,
#   'word_count': 486,
#   'syllable_count_per_word': 1.6292042657916326,
#   'personal_pronouns_count': 11,
#   'average_word_length': 4.587366694011485},
#  'blackassign0089.txt': {'positive_score': 14,
#   'negative_score': 41,
#   'polarity_score': -0.4909090819834713,
#   'subjective_score': 0.131264916154499,
#   'average_sentence_length': 18.49019607843137,
#   'percentage_of_complex_words': 0.20254506892895016,
#   'fog_index': 7.477096458944128,
#   'average_number_of_words_per_sentence': 18.49019607843137,
#   'complex_word_count': 191,
#   'word_count': 419,
#   'syllable_count_per_word': 1.7465535524920466,
#   'personal_pronouns_count': 4,
#   'average_word_length': 4.970307529162248},
#  'blackassign0058.txt': {'positive_score': 4,
#   'negative_score': 0,
#   'polarity_score': 0.9999997500000625,
#   'subjective_score': 0.04651162736614387,
#   'average_sentence_length': 13.916666666666666,
#   'percentage_of_complex_words': 0.32335329341317365,
#   'fog_index': 5.696007984031937,
#   'average_number_of_words_per_sentence': 13.916666666666666,
#   'complex_word_count': 54,
#   'word_count': 86,
#   'syllable_count_per_word': 2.035928143712575,
#   'personal_pronouns_count': 2,
#   'average_word_length': 5.437125748502994},
#  'blackassign0017.txt': {'positive_score': 48,
#   'negative_score': 11,
#   'polarity_score': 0.6271186334386673,
#   'subjective_score': 0.10727272707768595,
#   'average_sentence_length': 18.483870967741936,
#   'percentage_of_complex_words': 0.2774869109947644,
#   'fog_index': 7.50454315149468,
#   'average_number_of_words_per_sentence': 18.483870967741936,
#   'complex_word_count': 318,
#   'word_count': 550,
#   'syllable_count_per_word': 1.9162303664921465,
#   'personal_pronouns_count': 3,
#   'average_word_length': 5.440663176265271},
#  'blackassign0059.txt': {'positive_score': 19,
#   'negative_score': 37,
#   'polarity_score': -0.32142856568877565,
#   'subjective_score': 0.17948717891190008,
#   'average_sentence_length': 13.68421052631579,
#   'percentage_of_complex_words': 0.1717948717948718,
#   'fog_index': 5.542402159244265,
#   'average_number_of_words_per_sentence': 13.68421052631579,
#   'complex_word_count': 134,
#   'word_count': 312,
#   'syllable_count_per_word': 1.6294871794871795,
#   'personal_pronouns_count': 19,
#   'average_word_length': 4.6923076923076925},
#  'blackassign0069.txt': {'positive_score': 26,
#   'negative_score': 6,
#   'polarity_score': 0.6249999804687506,
#   'subjective_score': 0.20125786036944743,
#   'average_sentence_length': 29.1875,
#   'percentage_of_complex_words': 0.21199143468950749,
#   'fog_index': 11.759796573875803,
#   'average_number_of_words_per_sentence': 29.1875,
#   'complex_word_count': 99,
#   'word_count': 159,
#   'syllable_count_per_word': 1.6638115631691648,
#   'personal_pronouns_count': 8,
#   'average_word_length': 4.6788008565310495},
#  'blackassign0049.txt': {'positive_score': 0,
#   'negative_score': 0,
#   'polarity_score': 0.0,
#   'subjective_score': 0.0,
#   'average_sentence_length': 0,
#   'percentage_of_complex_words': 0,
#   'fog_index': 0.0,
#   'average_number_of_words_per_sentence': 0,
#   'complex_word_count': 0,
#   'word_count': 0,
#   'syllable_count_per_word': 0,
#   'personal_pronouns_count': 0,
#   'average_word_length': 0},
#  'blackassign0002.txt': {'positive_score': 51,
#   'negative_score': 31,
#   'polarity_score': 0.2439024360499703,
#   'subjective_score': 0.12148148130150892,
#   'average_sentence_length': 18.125,
#   'percentage_of_complex_words': 0.26482758620689656,
#   'fog_index': 7.355931034482758,
#   'average_number_of_words_per_sentence': 18.125,
#   'complex_word_count': 384,
#   'word_count': 675,
#   'syllable_count_per_word': 1.9475862068965517,
#   'personal_pronouns_count': 6,
#   'average_word_length': 5.4013793103448275},
#  'blackassign0073.txt': {'positive_score': 24,
#   'negative_score': 45,
#   'polarity_score': -0.3043478216761185,
#   'subjective_score': 0.12454873623727665,
#   'average_sentence_length': 21.545454545454547,
#   'percentage_of_complex_words': 0.17721518987341772,
#   'fog_index': 8.689067894131187,
#   'average_number_of_words_per_sentence': 21.545454545454547,
#   'complex_word_count': 210,
#   'word_count': 554,
#   'syllable_count_per_word': 1.6649789029535864,
#   'personal_pronouns_count': 4,
#   'average_word_length': 4.913080168776371},
#  'blackassign0016.txt': {'positive_score': 35,
#   'negative_score': 26,
#   'polarity_score': 0.14754098118785278,
#   'subjective_score': 0.10149750399085274,
#   'average_sentence_length': 20.05,
#   'percentage_of_complex_words': 0.27015793848711556,
#   'fog_index': 8.128063175394848,
#   'average_number_of_words_per_sentence': 20.05,
#   'complex_word_count': 325,
#   'word_count': 601,
#   'syllable_count_per_word': 1.8769742310889443,
#   'personal_pronouns_count': 7,
#   'average_word_length': 5.417290108063176},
#  'blackassign0080.txt': {'positive_score': 31,
#   'negative_score': 11,
#   'polarity_score': 0.476190464852608,
#   'subjective_score': 0.029370629350090466,
#   'average_sentence_length': 16.9010989010989,
#   'percentage_of_complex_words': 0.18888166449934982,
#   'fog_index': 6.8359922262393,
#   'average_number_of_words_per_sentence': 16.9010989010989,
#   'complex_word_count': 581,
#   'word_count': 1430,
#   'syllable_count_per_word': 1.6882314694408322,
#   'personal_pronouns_count': 2,
#   'average_word_length': 4.992522756827048},
#  'blackassign0054.txt': {'positive_score': 4,
#   'negative_score': 0,
#   'polarity_score': 0.9999997500000625,
#   'subjective_score': 0.022099447391715762,
#   'average_sentence_length': 20.833333333333332,
#   'percentage_of_complex_words': 0.18133333333333335,
#   'fog_index': 8.405866666666666,
#   'average_number_of_words_per_sentence': 20.833333333333332,
#   'complex_word_count': 68,
#   'word_count': 181,
#   'syllable_count_per_word': 1.7013333333333334,
#   'personal_pronouns_count': 0,
#   'average_word_length': 4.912},
#  'blackassign0044.txt': {'positive_score': 24,
#   'negative_score': 0,
#   'polarity_score': 0.999999958333335,
#   'subjective_score': 0.10084033571075489,
#   'average_sentence_length': 21.782608695652176,
#   'percentage_of_complex_words': 0.2894211576846307,
#   'fog_index': 8.828811941334724,
#   'average_number_of_words_per_sentence': 21.782608695652176,
#   'complex_word_count': 145,
#   'word_count': 238,
#   'syllable_count_per_word': 1.9301397205588822,
#   'personal_pronouns_count': 0,
#   'average_word_length': 5.347305389221557},
#  'blackassign0023.txt': {'positive_score': 25,
#   'negative_score': 15,
#   'polarity_score': 0.24999999375000018,
#   'subjective_score': 0.07130124764473932,
#   'average_sentence_length': 21.682539682539684,
#   'percentage_of_complex_words': 0.19472913616398244,
#   'fog_index': 8.750907527481466,
#   'average_number_of_words_per_sentence': 21.682539682539684,
#   'complex_word_count': 266,
#   'word_count': 561,
#   'syllable_count_per_word': 1.7664714494875549,
#   'personal_pronouns_count': 7,
#   'average_word_length': 4.961932650073207},
#  'blackassign0018.txt': {'positive_score': 30,
#   'negative_score': 10,
#   'polarity_score': 0.49999998750000035,
#   'subjective_score': 0.08113590247234097,
#   'average_sentence_length': 22.533333333333335,
#   'percentage_of_complex_words': 0.29191321499013806,
#   'fog_index': 9.13009861932939,
#   'average_number_of_words_per_sentence': 22.533333333333335,
#   'complex_word_count': 296,
#   'word_count': 493,
#   'syllable_count_per_word': 1.9151873767258383,
#   'personal_pronouns_count': 1,
#   'average_word_length': 5.4191321499013805},
#  'blackassign0012.txt': {'positive_score': 78,
#   'negative_score': 23,
#   'polarity_score': 0.5445544500539163,
#   'subjective_score': 0.12362301086459852,
#   'average_sentence_length': 20.75,
#   'percentage_of_complex_words': 0.30120481927710846,
#   'fog_index': 8.420481927710844,
#   'average_number_of_words_per_sentence': 20.75,
#   'complex_word_count': 500,
#   'word_count': 817,
#   'syllable_count_per_word': 1.997590361445783,
#   'personal_pronouns_count': 2,
#   'average_word_length': 5.53855421686747},
#  'blackassign0010.txt': {'positive_score': 128,
#   'negative_score': 180,
#   'polarity_score': -0.1688311682830157,
#   'subjective_score': 0.18803418791939303,
#   'average_sentence_length': 15.8008658008658,
#   'percentage_of_complex_words': 0.2841095890410959,
#   'fog_index': 6.43399015596276,
#   'average_number_of_words_per_sentence': 15.8008658008658,
#   'complex_word_count': 1037,
#   'word_count': 1638,
#   'syllable_count_per_word': 1.9424657534246574,
#   'personal_pronouns_count': 13,
#   'average_word_length': 5.3501369863013695},
#  'blackassign0088.txt': {'positive_score': 16,
#   'negative_score': 41,
#   'polarity_score': -0.43859648353339503,
#   'subjective_score': 0.06951219503718024,
#   'average_sentence_length': 30.157894736842106,
#   'percentage_of_complex_words': 0.25189063408958695,
#   'fog_index': 12.163914148372678,
#   'average_number_of_words_per_sentence': 30.157894736842106,
#   'complex_word_count': 433,
#   'word_count': 820,
#   'syllable_count_per_word': 1.8662012798138452,
#   'personal_pronouns_count': 1,
#   'average_word_length': 5.19022687609075},
#  'blackassign0085.txt': {'positive_score': 36,
#   'negative_score': 31,
#   'polarity_score': 0.074626864557808,
#   'subjective_score': 0.10166919559686009,
#   'average_sentence_length': 14.96694214876033,
#   'percentage_of_complex_words': 0.2037548315847598,
#   'fog_index': 6.068278792138036,
#   'average_number_of_words_per_sentence': 14.96694214876033,
#   'complex_word_count': 369,
#   'word_count': 659,
#   'syllable_count_per_word': 1.6769740474875758,
#   'personal_pronouns_count': 5,
#   'average_word_length': 4.856985091109884},
#  'blackassign0026.txt': {'positive_score': 21,
#   'negative_score': 15,
#   'polarity_score': 0.16666666203703717,
#   'subjective_score': 0.08352668194077335,
#   'average_sentence_length': 19.333333333333332,
#   'percentage_of_complex_words': 0.24942528735632183,
#   'fog_index': 7.833103448275861,
#   'average_number_of_words_per_sentence': 19.333333333333332,
#   'complex_word_count': 217,
#   'word_count': 431,
#   'syllable_count_per_word': 1.8563218390804597,
#   'personal_pronouns_count': 1,
#   'average_word_length': 5.145977011494253},
#  'blackassign0048.txt': {'positive_score': 3,
#   'negative_score': 4,
#   'polarity_score': -0.1428571224489825,
#   'subjective_score': 0.05072463731358959,
#   'average_sentence_length': 24.615384615384617,
#   'percentage_of_complex_words': 0.28125,
#   'fog_index': 9.958653846153847,
#   'average_number_of_words_per_sentence': 24.615384615384617,
#   'complex_word_count': 90,
#   'word_count': 138,
#   'syllable_count_per_word': 1.93125,
#   'personal_pronouns_count': 2,
#   'average_word_length': 5.3},
#  'blackassign0004.txt': {'positive_score': 35,
#   'negative_score': 74,
#   'polarity_score': -0.35779816185506275,
#   'subjective_score': 0.18664383529684275,
#   'average_sentence_length': 22.25531914893617,
#   'percentage_of_complex_words': 0.33938814531548755,
#   'fog_index': 9.037882917700664,
#   'average_number_of_words_per_sentence': 22.25531914893617,
#   'complex_word_count': 355,
#   'word_count': 584,
#   'syllable_count_per_word': 2.111854684512428,
#   'personal_pronouns_count': 5,
#   'average_word_length': 5.934990439770554},
#  'blackassign0011.txt': {'positive_score': 55,
#   'negative_score': 20,
#   'polarity_score': 0.46666666044444455,
#   'subjective_score': 0.09920634907512388,
#   'average_sentence_length': 24.0,
#   'percentage_of_complex_words': 0.3375706214689266,
#   'fog_index': 9.735028248587572,
#   'average_number_of_words_per_sentence': 24.0,
#   'complex_word_count': 478,
#   'word_count': 756,
#   'syllable_count_per_word': 2.0762711864406778,
#   'personal_pronouns_count': 3,
#   'average_word_length': 5.769774011299435},
#  'blackassign0021.txt': {'positive_score': 19,
#   'negative_score': 47,
#   'polarity_score': -0.42424241781450883,
#   'subjective_score': 0.13552361368475643,
#   'average_sentence_length': 20.04,
#   'percentage_of_complex_words': 0.2934131736526946,
#   'fog_index': 8.133365269461079,
#   'average_number_of_words_per_sentence': 20.04,
#   'complex_word_count': 294,
#   'word_count': 487,
#   'syllable_count_per_word': 1.9600798403193613,
#   'personal_pronouns_count': 6,
#   'average_word_length': 5.520958083832335},
#  'blackassign0071.txt': {'positive_score': 21,
#   'negative_score': 71,
#   'polarity_score': -0.5434782549621929,
#   'subjective_score': 0.25274725205289217,
#   'average_sentence_length': 12.441558441558442,
#   'percentage_of_complex_words': 0.17745302713987474,
#   'fog_index': 5.047604587479327,
#   'average_number_of_words_per_sentence': 12.441558441558442,
#   'complex_word_count': 170,
#   'word_count': 364,
#   'syllable_count_per_word': 1.638830897703549,
#   'personal_pronouns_count': 7,
#   'average_word_length': 4.689979123173278},
#  'blackassign0087.txt': {'positive_score': 29,
#   'negative_score': 32,
#   'polarity_score': -0.049180327062617595,
#   'subjective_score': 0.13203463174884278,
#   'average_sentence_length': 22.48936170212766,
#   'percentage_of_complex_words': 0.20340586565752128,
#   'fog_index': 9.077107027114073,
#   'average_number_of_words_per_sentence': 22.48936170212766,
#   'complex_word_count': 215,
#   'word_count': 462,
#   'syllable_count_per_word': 1.6982024597918637,
#   'personal_pronouns_count': 3,
#   'average_word_length': 4.938505203405866},
#  'blackassign0077.txt': {'positive_score': 23,
#   'negative_score': 13,
#   'polarity_score': 0.2777777700617286,
#   'subjective_score': 0.10344827556480381,
#   'average_sentence_length': 28.11111111111111,
#   'percentage_of_complex_words': 0.1963109354413702,
#   'fog_index': 11.322968818620993,
#   'average_number_of_words_per_sentence': 28.11111111111111,
#   'complex_word_count': 149,
#   'word_count': 348,
#   'syllable_count_per_word': 1.7470355731225296,
#   'personal_pronouns_count': 1,
#   'average_word_length': 5.081686429512517},
#  'blackassign0062.txt': {'positive_score': 7,
#   'negative_score': 18,
#   'polarity_score': -0.4399999824000007,
#   'subjective_score': 0.10869565170132325,
#   'average_sentence_length': 16.96875,
#   'percentage_of_complex_words': 0.1860036832412523,
#   'fog_index': 6.861901473296502,
#   'average_number_of_words_per_sentence': 16.96875,
#   'complex_word_count': 101,
#   'word_count': 230,
#   'syllable_count_per_word': 1.6887661141804788,
#   'personal_pronouns_count': 11,
#   'average_word_length': 4.941068139963168},
#  'blackassign0057.txt': {'positive_score': 14,
#   'negative_score': 9,
#   'polarity_score': 0.21739129489603065,
#   'subjective_score': 0.1554054043553689,
#   'average_sentence_length': 13.586206896551724,
#   'percentage_of_complex_words': 0.18274111675126903,
#   'fog_index': 5.507579205321197,
#   'average_number_of_words_per_sentence': 13.586206896551724,
#   'complex_word_count': 72,
#   'word_count': 148,
#   'syllable_count_per_word': 1.8020304568527918,
#   'personal_pronouns_count': 0,
#   'average_word_length': 5.149746192893401},
#  'blackassign0081.txt': {'positive_score': 32,
#   'negative_score': 41,
#   'polarity_score': -0.12328766954400452,
#   'subjective_score': 0.09878213789068722,
#   'average_sentence_length': 21.012048192771083,
#   'percentage_of_complex_words': 0.21961009174311927,
#   'fog_index': 8.492663313805682,
#   'average_number_of_words_per_sentence': 21.012048192771083,
#   'complex_word_count': 383,
#   'word_count': 739,
#   'syllable_count_per_word': 1.7597477064220184,
#   'personal_pronouns_count': 7,
#   'average_word_length': 4.963876146788991},
#  'blackassign0082.txt': {'positive_score': 28,
#   'negative_score': 69,
#   'polarity_score': -0.42268040801360407,
#   'subjective_score': 0.12294043076940377,
#   'average_sentence_length': 24.883333333333333,
#   'percentage_of_complex_words': 0.2813127930341594,
#   'fog_index': 10.065858450546997,
#   'average_number_of_words_per_sentence': 24.883333333333333,
#   'complex_word_count': 420,
#   'word_count': 789,
#   'syllable_count_per_word': 1.943067649028801,
#   'personal_pronouns_count': 0,
#   'average_word_length': 5.490957803081045},
#  'blackassign0068.txt': {'positive_score': 38,
#   'negative_score': 7,
#   'polarity_score': 0.6888888735802473,
#   'subjective_score': 0.09635974283434745,
#   'average_sentence_length': 20.776119402985074,
#   'percentage_of_complex_words': 0.15660919540229884,
#   'fog_index': 8.37309143935495,
#   'average_number_of_words_per_sentence': 20.776119402985074,
#   'complex_word_count': 218,
#   'word_count': 467,
#   'syllable_count_per_word': 1.5754310344827587,
#   'personal_pronouns_count': 4,
#   'average_word_length': 4.533045977011494},
#  'blackassign0030.txt': {'positive_score': 58,
#   'negative_score': 37,
#   'polarity_score': 0.22105262925207758,
#   'subjective_score': 0.17657992532234215,
#   'average_sentence_length': 17.2625,
#   'percentage_of_complex_words': 0.1889934829833454,
#   'fog_index': 6.980597393193339,
#   'average_number_of_words_per_sentence': 17.2625,
#   'complex_word_count': 261,
#   'word_count': 538,
#   'syllable_count_per_word': 1.6806661839246924,
#   'personal_pronouns_count': 6,
#   'average_word_length': 4.810282404055033},
#  'blackassign0091.txt': {'positive_score': 21,
#   'negative_score': 27,
#   'polarity_score': -0.1249999973958334,
#   'subjective_score': 0.10859728482217809,
#   'average_sentence_length': 29.405405405405407,
#   'percentage_of_complex_words': 0.21966911764705882,
#   'fog_index': 11.850029809220986,
#   'average_number_of_words_per_sentence': 29.405405405405407,
#   'complex_word_count': 239,
#   'word_count': 442,
#   'syllable_count_per_word': 1.7463235294117647,
#   'personal_pronouns_count': 12,
#   'average_word_length': 4.938419117647059},
#  'blackassign0064.txt': {'positive_score': 25,
#   'negative_score': 49,
#   'polarity_score': -0.32432431994156324,
#   'subjective_score': 0.09585492215562834,
#   'average_sentence_length': 22.586666666666666,
#   'percentage_of_complex_words': 0.26387249114521844,
#   'fog_index': 9.140215663124755,
#   'average_number_of_words_per_sentence': 22.586666666666666,
#   'complex_word_count': 447,
#   'word_count': 772,
#   'syllable_count_per_word': 1.87012987012987,
#   'personal_pronouns_count': 16,
#   'average_word_length': 5.3276269185360094},
#  'blackassign0025.txt': {'positive_score': 15,
#   'negative_score': 10,
#   'polarity_score': 0.19999999200000032,
#   'subjective_score': 0.05924170602075425,
#   'average_sentence_length': 27.56756756756757,
#   'percentage_of_complex_words': 0.1676470588235294,
#   'fog_index': 11.09408585055644,
#   'average_number_of_words_per_sentence': 27.56756756756757,
#   'complex_word_count': 171,
#   'word_count': 422,
#   'syllable_count_per_word': 1.6539215686274509,
#   'personal_pronouns_count': 6,
#   'average_word_length': 4.709803921568628},
#  'blackassign0050.txt': {'positive_score': 23,
#   'negative_score': 67,
#   'polarity_score': -0.4888888834567902,
#   'subjective_score': 0.14539579944201,
#   'average_sentence_length': 24.160714285714285,
#   'percentage_of_complex_words': 0.22172949002217296,
#   'fog_index': 9.752977510294585,
#   'average_number_of_words_per_sentence': 24.160714285714285,
#   'complex_word_count': 300,
#   'word_count': 619,
#   'syllable_count_per_word': 1.7967479674796747,
#   'personal_pronouns_count': 2,
#   'average_word_length': 5.059866962305986},
#  'blackassign0079.txt': {'positive_score': 29,
#   'negative_score': 50,
#   'polarity_score': -0.26582278144528126,
#   'subjective_score': 0.10851648336742241,
#   'average_sentence_length': 21.32051282051282,
#   'percentage_of_complex_words': 0.22669873722188816,
#   'fog_index': 8.618884623093884,
#   'average_number_of_words_per_sentence': 21.32051282051282,
#   'complex_word_count': 377,
#   'word_count': 728,
#   'syllable_count_per_word': 1.7528562838244137,
#   'personal_pronouns_count': 6,
#   'average_word_length': 5.032471437161756},
#  'blackassign0051.txt': {'positive_score': 16,
#   'negative_score': 14,
#   'polarity_score': 0.06666666444444451,
#   'subjective_score': 0.10067114060177469,
#   'average_sentence_length': 23.8,
#   'percentage_of_complex_words': 0.22128851540616246,
#   'fog_index': 9.608515406162466,
#   'average_number_of_words_per_sentence': 23.8,
#   'complex_word_count': 158,
#   'word_count': 298,
#   'syllable_count_per_word': 1.7745098039215685,
#   'personal_pronouns_count': 4,
#   'average_word_length': 4.928571428571429},
#  'blackassign0006.txt': {'positive_score': 85,
#   'negative_score': 26,
#   'polarity_score': 0.5315315267429592,
#   'subjective_score': 0.11280487793414139,
#   'average_sentence_length': 22.89873417721519,
#   'percentage_of_complex_words': 0.31730237700386954,
#   'fog_index': 9.286414621687625,
#   'average_number_of_words_per_sentence': 22.89873417721519,
#   'complex_word_count': 574,
#   'word_count': 984,
#   'syllable_count_per_word': 2.0541735765616362,
#   'personal_pronouns_count': 6,
#   'average_word_length': 5.902155887230514},
#  'blackassign0086.txt': {'positive_score': 46,
#   'negative_score': 15,
#   'polarity_score': 0.5081967129803818,
#   'subjective_score': 0.08425414353003571,
#   'average_sentence_length': 18.225806451612904,
#   'percentage_of_complex_words': 0.215929203539823,
#   'fog_index': 7.376694262061091,
#   'average_number_of_words_per_sentence': 18.225806451612904,
#   'complex_word_count': 366,
#   'word_count': 724,
#   'syllable_count_per_word': 1.7345132743362832,
#   'personal_pronouns_count': 5,
#   'average_word_length': 4.972271386430679},
#  'blackassign0036.txt': {'positive_score': 0,
#   'negative_score': 0,
#   'polarity_score': 0.0,
#   'subjective_score': 0.0,
#   'average_sentence_length': 0,
#   'percentage_of_complex_words': 0,
#   'fog_index': 0.0,
#   'average_number_of_words_per_sentence': 0,
#   'complex_word_count': 0,
#   'word_count': 0,
#   'syllable_count_per_word': 0,
#   'personal_pronouns_count': 0,
#   'average_word_length': 0},
#  'blackassign0003.txt': {'positive_score': 36,
#   'negative_score': 23,
#   'polarity_score': 0.22033897931628849,
#   'subjective_score': 0.09932659915938283,
#   'average_sentence_length': 18.45614035087719,
#   'percentage_of_complex_words': 0.3602661596958175,
#   'fog_index': 7.526562604229205,
#   'average_number_of_words_per_sentence': 18.45614035087719,
#   'complex_word_count': 379,
#   'word_count': 594,
#   'syllable_count_per_word': 2.208174904942966,
#   'personal_pronouns_count': 13,
#   'average_word_length': 6.061787072243346},
#  'blackassign0063.txt': {'positive_score': 21,
#   'negative_score': 37,
#   'polarity_score': -0.2758620642092748,
#   'subjective_score': 0.13394919137656075,
#   'average_sentence_length': 19.830188679245282,
#   'percentage_of_complex_words': 0.1845861084681256,
#   'fog_index': 8.005909915085363,
#   'average_number_of_words_per_sentence': 19.830188679245282,
#   'complex_word_count': 194,
#   'word_count': 433,
#   'syllable_count_per_word': 1.7050428163653664,
#   'personal_pronouns_count': 7,
#   'average_word_length': 4.801141769743102},
#  'blackassign0053.txt': {'positive_score': 40,
#   'negative_score': 3,
#   'polarity_score': 0.8604650962682536,
#   'subjective_score': 0.1382636651502776,
#   'average_sentence_length': 16.65,
#   'percentage_of_complex_words': 0.23873873873873874,
#   'fog_index': 6.755495495495495,
#   'average_number_of_words_per_sentence': 16.65,
#   'complex_word_count': 159,
#   'word_count': 311,
#   'syllable_count_per_word': 1.867867867867868,
#   'personal_pronouns_count': 4,
#   'average_word_length': 5.117117117117117},
#  'blackassign0019.txt': {'positive_score': 58,
#   'negative_score': 6,
#   'polarity_score': 0.8124999873046878,
#   'subjective_score': 0.08050314455282623,
#   'average_sentence_length': 17.6875,
#   'percentage_of_complex_words': 0.2744405182567727,
#   'fog_index': 7.184776207302709,
#   'average_number_of_words_per_sentence': 17.6875,
#   'complex_word_count': 466,
#   'word_count': 795,
#   'syllable_count_per_word': 1.8451118963486455,
#   'personal_pronouns_count': 5,
#   'average_word_length': 5.283863368669023},
#  'blackassign0007.txt': {'positive_score': 29,
#   'negative_score': 65,
#   'polarity_score': -0.38297871933001365,
#   'subjective_score': 0.15064102539961374,
#   'average_sentence_length': 18.142857142857142,
#   'percentage_of_complex_words': 0.25196850393700787,
#   'fog_index': 7.35793025871766,
#   'average_number_of_words_per_sentence': 18.142857142857142,
#   'complex_word_count': 320,
#   'word_count': 624,
#   'syllable_count_per_word': 1.888976377952756,
#   'personal_pronouns_count': 1,
#   'average_word_length': 5.233070866141732},
#  'blackassign0046.txt': {'positive_score': 23,
#   'negative_score': 0,
#   'polarity_score': 0.999999956521741,
#   'subjective_score': 0.05251141540522508,
#   'average_sentence_length': 16.910714285714285,
#   'percentage_of_complex_words': 0.2713833157338965,
#   'fog_index': 6.872839040579272,
#   'average_number_of_words_per_sentence': 16.910714285714285,
#   'complex_word_count': 257,
#   'word_count': 438,
#   'syllable_count_per_word': 1.8405491024287224,
#   'personal_pronouns_count': 0,
#   'average_word_length': 5.157338965153115},
#  'blackassign0074.txt': {'positive_score': 29,
#   'negative_score': 24,
#   'polarity_score': 0.0943396208615166,
#   'subjective_score': 0.07875185723811017,
#   'average_sentence_length': 17.45679012345679,
#   'percentage_of_complex_words': 0.2333804809052334,
#   'fog_index': 7.07606824174481,
#   'average_number_of_words_per_sentence': 17.45679012345679,
#   'complex_word_count': 330,
#   'word_count': 673,
#   'syllable_count_per_word': 1.8408769448373408,
#   'personal_pronouns_count': 9,
#   'average_word_length': 5.087694483734087},
#  'blackassign0015.txt': {'positive_score': 35,
#   'negative_score': 26,
#   'polarity_score': 0.14754098118785278,
#   'subjective_score': 0.10149750399085274,
#   'average_sentence_length': 20.05,
#   'percentage_of_complex_words': 0.27015793848711556,
#   'fog_index': 8.128063175394848,
#   'average_number_of_words_per_sentence': 20.05,
#   'complex_word_count': 325,
#   'word_count': 601,
#   'syllable_count_per_word': 1.8769742310889443,
#   'personal_pronouns_count': 7,
#   'average_word_length': 5.417290108063176},
#  'blackassign0014.txt': {'positive_score': 0,
#   'negative_score': 0,
#   'polarity_score': 0.0,
#   'subjective_score': 0.0,
#   'average_sentence_length': 11.0,
#   'percentage_of_complex_words': 0.0,
#   'fog_index': 4.4,
#   'average_number_of_words_per_sentence': 11.0,
#   'complex_word_count': 0,
#   'word_count': 4,
#   'syllable_count_per_word': 1.1818181818181819,
#   'personal_pronouns_count': 0,
#   'average_word_length': 3.5454545454545454},
#  'blackassign0028.txt': {'positive_score': 28,
#   'negative_score': 24,
#   'polarity_score': 0.07692307544378701,
#   'subjective_score': 0.1090146748238686,
#   'average_sentence_length': 25.829268292682926,
#   'percentage_of_complex_words': 0.2474032105760151,
#   'fog_index': 10.430668601303577,
#   'average_number_of_words_per_sentence': 25.829268292682926,
#   'complex_word_count': 262,
#   'word_count': 477,
#   'syllable_count_per_word': 1.8035882908404155,
#   'personal_pronouns_count': 9,
#   'average_word_length': 5.1794145420207744},
#  'blackassign0075.txt': {'positive_score': 21,
#   'negative_score': 79,
#   'polarity_score': -0.5799999942,
#   'subjective_score': 0.25906735684179444,
#   'average_sentence_length': 12.55,
#   'percentage_of_complex_words': 0.18326693227091634,
#   'fog_index': 5.093306772908367,
#   'average_number_of_words_per_sentence': 12.55,
#   'complex_word_count': 184,
#   'word_count': 386,
#   'syllable_count_per_word': 1.653386454183267,
#   'personal_pronouns_count': 8,
#   'average_word_length': 4.729083665338646},
#  'blackassign0055.txt': {'positive_score': 24,
#   'negative_score': 9,
#   'polarity_score': 0.45454544077135034,
#   'subjective_score': 0.06457925623370009,
#   'average_sentence_length': 23.659574468085108,
#   'percentage_of_complex_words': 0.20863309352517986,
#   'fog_index': 9.547283024644114,
#   'average_number_of_words_per_sentence': 23.659574468085108,
#   'complex_word_count': 232,
#   'word_count': 511,
#   'syllable_count_per_word': 1.7032374100719425,
#   'personal_pronouns_count': 4,
#   'average_word_length': 4.8003597122302155},
#  'blackassign0056.txt': {'positive_score': 24,
#   'negative_score': 8,
#   'polarity_score': 0.49999998437500054,
#   'subjective_score': 0.10389610355877889,
#   'average_sentence_length': 25.166666666666668,
#   'percentage_of_complex_words': 0.2847682119205298,
#   'fog_index': 10.18057395143488,
#   'average_number_of_words_per_sentence': 25.166666666666668,
#   'complex_word_count': 172,
#   'word_count': 308,
#   'syllable_count_per_word': 1.9321192052980132,
#   'personal_pronouns_count': 1,
#   'average_word_length': 5.324503311258278},
#  'blackassign0076.txt': {'positive_score': 37,
#   'negative_score': 33,
#   'polarity_score': 0.05714285632653063,
#   'subjective_score': 0.11437908478042633,
#   'average_sentence_length': 24.634920634920636,
#   'percentage_of_complex_words': 0.19716494845360824,
#   'fog_index': 9.932834233349698,
#   'average_number_of_words_per_sentence': 24.634920634920636,
#   'complex_word_count': 306,
#   'word_count': 612,
#   'syllable_count_per_word': 1.6829896907216495,
#   'personal_pronouns_count': 5,
#   'average_word_length': 4.792525773195877},
#  'blackassign0065.txt': {'positive_score': 42,
#   'negative_score': 22,
#   'polarity_score': 0.31249999511718757,
#   'subjective_score': 0.09411764692041523,
#   'average_sentence_length': 25.485294117647058,
#   'percentage_of_complex_words': 0.16907097518753605,
#   'fog_index': 10.26174603713384,
#   'average_number_of_words_per_sentence': 25.485294117647058,
#   'complex_word_count': 293,
#   'word_count': 680,
#   'syllable_count_per_word': 1.6555106751298327,
#   'personal_pronouns_count': 19,
#   'average_word_length': 4.727639930755915},
#  'blackassign0024.txt': {'positive_score': 20,
#   'negative_score': 3,
#   'polarity_score': 0.7391304026465042,
#   'subjective_score': 0.09090909054976644,
#   'average_sentence_length': 29.05263157894737,
#   'percentage_of_complex_words': 0.2572463768115942,
#   'fog_index': 11.723951182303587,
#   'average_number_of_words_per_sentence': 29.05263157894737,
#   'complex_word_count': 142,
#   'word_count': 253,
#   'syllable_count_per_word': 1.8333333333333333,
#   'personal_pronouns_count': 1,
#   'average_word_length': 5.166666666666667},
#  'blackassign0041.txt': {'positive_score': 29,
#   'negative_score': 28,
#   'polarity_score': 0.017543859341335802,
#   'subjective_score': 0.1032608693781506,
#   'average_sentence_length': 15.126582278481013,
#   'percentage_of_complex_words': 0.22426778242677825,
#   'fog_index': 6.140340024363117,
#   'average_number_of_words_per_sentence': 15.126582278481013,
#   'complex_word_count': 268,
#   'word_count': 552,
#   'syllable_count_per_word': 1.7439330543933054,
#   'personal_pronouns_count': 6,
#   'average_word_length': 4.9715481171548115},
#  'blackassign0038.txt': {'positive_score': 63,
#   'negative_score': 33,
#   'polarity_score': 0.31249999674479173,
#   'subjective_score': 0.11123986082127478,
#   'average_sentence_length': 25.901234567901234,
#   'percentage_of_complex_words': 0.21877979027645378,
#   'fog_index': 10.448005743271075,
#   'average_number_of_words_per_sentence': 25.901234567901234,
#   'complex_word_count': 459,
#   'word_count': 863,
#   'syllable_count_per_word': 1.7578646329837941,
#   'personal_pronouns_count': 9,
#   'average_word_length': 4.840324118207817},
#  'blackassign0093.txt': {'positive_score': 3,
#   'negative_score': 3,
#   'polarity_score': 0.0,
#   'subjective_score': 0.09230769088757398,
#   'average_sentence_length': 18.5,
#   'percentage_of_complex_words': 0.13513513513513514,
#   'fog_index': 7.454054054054055,
#   'average_number_of_words_per_sentence': 18.5,
#   'complex_word_count': 25,
#   'word_count': 65,
#   'syllable_count_per_word': 1.545945945945946,
#   'personal_pronouns_count': 2,
#   'average_word_length': 4.416216216216216},
#  'blackassign0037.txt': {'positive_score': 32,
#   'negative_score': 13,
#   'polarity_score': 0.4222222128395064,
#   'subjective_score': 0.14657980408280194,
#   'average_sentence_length': 19.77777777777778,
#   'percentage_of_complex_words': 0.18820224719101122,
#   'fog_index': 7.986392009987516,
#   'average_number_of_words_per_sentence': 19.77777777777778,
#   'complex_word_count': 134,
#   'word_count': 307,
#   'syllable_count_per_word': 1.6474719101123596,
#   'personal_pronouns_count': 0,
#   'average_word_length': 4.782303370786517},
#  'blackassign0097.txt': {'positive_score': 21,
#   'negative_score': 35,
#   'polarity_score': -0.24999999553571436,
#   'subjective_score': 0.14322250602756392,
#   'average_sentence_length': 27.384615384615383,
#   'percentage_of_complex_words': 0.1694756554307116,
#   'fog_index': 11.021636416018438,
#   'average_number_of_words_per_sentence': 27.384615384615383,
#   'complex_word_count': 181,
#   'word_count': 391,
#   'syllable_count_per_word': 1.6058052434456929,
#   'personal_pronouns_count': 5,
#   'average_word_length': 4.670411985018727},
#  'blackassign0067.txt': {'positive_score': 24,
#   'negative_score': 7,
#   'polarity_score': 0.5483870790842877,
#   'subjective_score': 0.10652920925591337,
#   'average_sentence_length': 13.935483870967742,
#   'percentage_of_complex_words': 0.1724537037037037,
#   'fog_index': 5.643175029868579,
#   'average_number_of_words_per_sentence': 13.935483870967742,
#   'complex_word_count': 149,
#   'word_count': 291,
#   'syllable_count_per_word': 1.6226851851851851,
#   'personal_pronouns_count': 1,
#   'average_word_length': 4.556712962962963},
#  'blackassign0033.txt': {'positive_score': 55,
#   'negative_score': 25,
#   'polarity_score': 0.37499999531250006,
#   'subjective_score': 0.10884353726687954,
#   'average_sentence_length': 21.1625,
#   'percentage_of_complex_words': 0.21795629060838748,
#   'fog_index': 8.552182516243356,
#   'average_number_of_words_per_sentence': 21.1625,
#   'complex_word_count': 369,
#   'word_count': 735,
#   'syllable_count_per_word': 1.7731836975782633,
#   'personal_pronouns_count': 16,
#   'average_word_length': 5.019492025989368},
#  'blackassign0040.txt': {'positive_score': 32,
#   'negative_score': 24,
#   'polarity_score': 0.1428571403061225,
#   'subjective_score': 0.0973913041784499,
#   'average_sentence_length': 20.220338983050848,
#   'percentage_of_complex_words': 0.28415758591785417,
#   'fog_index': 8.20179862758748,
#   'average_number_of_words_per_sentence': 20.220338983050848,
#   'complex_word_count': 339,
#   'word_count': 575,
#   'syllable_count_per_word': 1.9245599329421625,
#   'personal_pronouns_count': 10,
#   'average_word_length': 5.424140821458508},
#  'blackassign0094.txt': {'positive_score': 24,
#   'negative_score': 42,
#   'polarity_score': -0.27272726859504137,
#   'subjective_score': 0.1413276228237096,
#   'average_sentence_length': 18.116666666666667,
#   'percentage_of_complex_words': 0.1968721251149954,
#   'fog_index': 7.325415516712666,
#   'average_number_of_words_per_sentence': 18.116666666666667,
#   'complex_word_count': 214,
#   'word_count': 467,
#   'syllable_count_per_word': 1.6918123275068997,
#   'personal_pronouns_count': 13,
#   'average_word_length': 4.790248390064398},
#  'blackassign0020.txt': {'positive_score': 0,
#   'negative_score': 0,
#   'polarity_score': 0.0,
#   'subjective_score': 0.0,
#   'average_sentence_length': 6.0,
#   'percentage_of_complex_words': 0.3333333333333333,
#   'fog_index': 2.533333333333333,
#   'average_number_of_words_per_sentence': 6.0,
#   'complex_word_count': 2,
#   'word_count': 3,
#   'syllable_count_per_word': 2.3333333333333335,
#   'personal_pronouns_count': 0,
#   'average_word_length': 6.5}}
